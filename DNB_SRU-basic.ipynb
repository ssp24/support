# %% [markdown]
# # DNBLab Jupyter Notebook Tutorial
#
# ## Abfrage der SRU-Schnittstelle

# %% [markdown]
# ### Einrichten der Arbeitsumgebung  <a class="anchor" id="Teil1"></a>

# %%
import requests
import pandas as pd
import lxml.etree as ET
from bs4 import BeautifulSoup as soup
import unicodedata

# %% [markdown]
# ### Schnelle Abfrage (100 erste Treffer, nur Rückgabe der Treffermenge)  <a class="anchor" id="Teil1"></a>

# %%
def sru_dnb_simple(query): 

    dnb_url = "https://services.dnb.de/sru/dnb"
    parameter = {'version' : '1.1' , 'operation' : 'searchRetrieve' , 'query' : query,
                 'recordSchema' : 'MARC21-xml', 'maximumRecords': '100'} 

    r = requests.get(dnb_url, params = parameter)
    response = soup(r.content)
    number = response.find_all('numberofrecords')[0].text
    
    return number

# %%
myquery1 = sru_dnb_simple('catalog=dnb.hss and diss* and sgt="300" or sgt="500" or sgt="600" and jhr="1980"')
print(myquery1, "Ergebnisse")
# Out:
# 8044 Ergebnisse

# %% [markdown]
# ### Richtige Abfrage

# %%
def dnb_sru(query):
    
    base_url = "https://services.dnb.de/sru/dnb"
    params = {'recordSchema' : 'MARC21-xml',
          'operation': 'searchRetrieve',
          'version': '1.1',
          'maximumRecords': '100',
          'query': query
         }
    r = requests.get(base_url, params=params)
    xml = soup(r.content)
    records = xml.find_all('record', {'type':'Bibliographic'})
    
    if len(records) < 100:
        
        return records
    
    else:
        
        num_results = 100
        i = 101
        while num_results == 100:
            
            params.update({'startRecord': i})
            r = requests.get(base_url, params=params)
            xml = soup(r.content)
            new_records = xml.find_all('record', {'type':'Bibliographic'})
            records+=new_records
            i+=100
            num_results = len(new_records)
            
        return records

# %%
#myquery = sru_dnb('hss all "diss*" and jhr within "* 2020" and jhr within "1980 *"')
myquery = dnb_sru('catalog="dnb.hss" and diss* and sgt="600" and jhr="2010"')
print(len(myquery), "Ergebnisse")
# Out:
# 108 Ergebnisse

# %% [markdown]
# ### Verarbeiten der Ergebnisse  <a class="anchor" id="Teil4"></a>

# %%
def parse_record(record):
    
    ns = {"marc":"http://www.loc.gov/MARC21/slim"}
    xml = ET.fromstring(unicodedata.normalize("NFC", str(record)))
    
    #idn
    idn = xml.xpath("marc:controlfield[@tag = '001']", namespaces=ns)
    try:
        idn = idn[0].text
    except:
        idn = 'fail'
    
    # titel
    titel = xml.xpath("marc:datafield[@tag = '245']/marc:subfield[@code = 'a']", namespaces=ns)
    try:
        titel = titel[0].text
    except:
        titel = "unknown"
        
    
    # author
    author = xml.xpath("marc:datafield[@tag = '100']/marc:subfield[@code = 'a']", namespaces=ns)
    try:
        author = author[0].text
    except:
        author = "unknown"
        
        
    #gnd
    gnd = xml.xpath("marc:datafield[@tag = '100']/marc:subfield[@code = '0']", namespaces=ns)
    try:
        gnd = gnd[0].text
    except:
        gnd = "none"
  

    # supervisor (maybe):
    superv = xml.xpath("marc:datafield[@tag = '700']/marc:subfield[@code = 'a']", namespaces=ns)
    superrole = xml.xpath("marc:datafield[@tag = '700']/marc:subfield[@code = 'e']", namespaces=ns)
    try:
        superv = superv[0].text
        superrole = superrole[0].text
        supervisor = superv + " - " + superrole
    except:
        supervisor = "unknown"
    
    
    meta_dict = {"idn":idn, "titel":titel, "author":author, "gnd":gnd, "supervisor":supervisor}
    
    return meta_dict

# %%
output = [parse_record(record) for record in myquery]
df = pd.DataFrame(output)
df
# Out:
#             idn                                              titel  \
# 0    100822880X  A method for the comparison of transport air...
# 1    1007183780  A new approach to establish tactility in min...
# 2    1003606326  Abiotically catalyzed glucose fuel cells for p...
# 3    1008306487    Adaptive functional modeling of neural activity
# 4    1009326414  Analog Integrated CMOS Circuits for the Readou...
# ..          ...                                                ...
# 103  1000185826  Vergleich der Materialkennwerte von Formstoffe...
# 104  100513264X  Verifying and allocating real-time tasks on di...
# 105  1007432985  Web service discovery based on semantic inform...
# 106  1010986694  Welchen Einfluss haben das verwendete Bypassma...
# 107  1003785581  Zur Diagnose und integrierten Bekämpfung Holz ...
#
#                               author                 gnd supervisor
# 0                     Gologan, Corin   (DE-588)142739642    unknown
# 1                   Kübler, Bernhard   (DE-588)142331783    unknown
# 2                 Kerzenmacher, Sven  (DE-588)1105594211    unknown
# 3                      Gürel, Tayfun                none    unknown
# 4    Karagounis, Michael Athanassios   (DE-588)143188321    unknown
# ..                               ...                 ...        ...
# 103                Weltschev, Margit   (DE-588)140308385    unknown
# 104                Masrur, Alejandro   (DE-588)141928689    unknown
# 105                  Schulte, Stefan   (DE-588)135768713    unknown
# 106                     Porath, Mark   (DE-588)143129570    unknown
# 107                   Haustein, Tilo   (DE-588)131629158    unknown
#
# [108 rows x 5 columns]

# %%
df.to_csv("Abfrage.csv", index=False)

# %%
df.to_excel("Abfrage.xlsx", index=False, encoding='utf8')

# %% [markdown]
# ### Filtern des Dataframe

# %%
## Show all items where no author was found: 

noauthors = df.query('author == "unknown"')
noauthors
# Out:
# Empty DataFrame
# Columns: [idn, titel, author]
# Index: []

# %%
print(myquery[0])
# Out:
# <record type="Bibliographic" xmlns="http://www.loc.gov/MARC21/slim">
# <leader>00000nam a2200000uc 4500</leader>
# <controlfield tag="001">1253067287</controlfield>
# <controlfield tag="003">DE-101</controlfield>
# <controlfield tag="005">20220308223115.0</controlfield>
# <controlfield tag="007">cr||||||||||||</controlfield>
# <controlfield tag="008">220308s2022    gw |||||om||| 00||||eng  </controlfield>
# <datafield ind1=" " ind2=" " tag="015">
# <subfield code="a">22,O04</subfield>
# <subfield code="2">dnb</subfield>
# </datafield>
# <datafield ind1="7" ind2=" " tag="016">
# <subfield code="2">DE-101</subfield>
# <subfield code="a">1253067287</subfield>
# </datafield>
# <datafield ind1="7" ind2=" " tag="024">
# <subfield code="2">urn</subfield>
# <subfield code="a">urn:nbn:de:bsz:21-dspace-994892</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="035">
# <subfield code="a">(DE-599)DNB1253067287</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="040">
# <subfield code="a">1240</subfield>
# <subfield code="b">ger</subfield>
# <subfield code="c">DE-101</subfield>
# <subfield code="d">9999</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="041">
# <subfield code="8">1\p</subfield>
# <subfield code="a">eng</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="044">
# <subfield code="c">XA-DE-BW</subfield>
# </datafield>
# <datafield ind1="7" ind2="4" tag="082">
# <subfield code="8">6\p</subfield>
# <subfield code="a">617.7</subfield>
# <subfield code="q">DE-101</subfield>
# <subfield code="2">23kdnb</subfield>
# </datafield>
# <datafield ind1="7" ind2=" " tag="083">
# <subfield code="8">7\p</subfield>
# <subfield code="a">610</subfield>
# <subfield code="q">DE-101</subfield>
# <subfield code="2">23sdnb</subfield>
# </datafield>
# <datafield ind1="1" ind2=" " tag="100">
# <subfield code="8">2\p</subfield>
# <subfield code="a">Speck, Achim</subfield>
# <subfield code="e">Verfasser</subfield>
# <subfield code="4">aut</subfield>
# </datafield>
# <datafield ind1="1" ind2="0" tag="245">
# <subfield code="a">A Data-Based Artificial Neural Network Assisted Testing Framework for the Assessment of Electrical Stimulation Patterns for Retinal Implants</subfield>
# <subfield code="c">Achim Speck ; Betreuer: Eberhart Zrenner</subfield>
# </datafield>
# <datafield ind1=" " ind2="1" tag="264">
# <subfield code="a">Tübingen</subfield>
# <subfield code="b">Universitätsbibliothek Tübingen</subfield>
# <subfield code="c">2022</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="300">
# <subfield code="a">Online-Ressource</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="336">
# <subfield code="a">Text</subfield>
# <subfield code="b">txt</subfield>
# <subfield code="2">rdacontent</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="337">
# <subfield code="a">Computermedien</subfield>
# <subfield code="b">c</subfield>
# <subfield code="2">rdamedia</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="338">
# <subfield code="a">Online-Ressource</subfield>
# <subfield code="b">cr</subfield>
# <subfield code="2">rdacarrier</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="502">
# <subfield code="b">Dissertation</subfield>
# <subfield code="c">Tübingen, Universität Tübingen</subfield>
# <subfield code="d">2020</subfield>
# </datafield>
# <datafield ind1="1" ind2=" " tag="583">
# <subfield code="a">Archivierung/Langzeitarchivierung gewährleistet</subfield>
# <subfield code="5">DE-101</subfield>
# <subfield code="2">pdager</subfield>
# </datafield>
# <datafield ind1=" " ind2="7" tag="650">
# <subfield code="8">4\p</subfield>
# <subfield code="a">Testing</subfield>
# <subfield code="0">(DLC)sh85134146</subfield>
# <subfield code="0">http://id.loc.gov/authorities/subjects/sh85134146</subfield>
# <subfield code="2">lcsh</subfield>
# </datafield>
# <datafield ind1=" " ind2="7" tag="650">
# <subfield code="8">5\p</subfield>
# <subfield code="a">Evaluation</subfield>
# <subfield code="0">(DLC)sh85045926</subfield>
# <subfield code="0">http://id.loc.gov/authorities/subjects/sh85045926</subfield>
# <subfield code="2">lcsh</subfield>
# </datafield>
# <datafield ind1=" " ind2="7" tag="650">
# <subfield code="a">Maschinelles Lernen ; Mustererkennung ; Netzhaut</subfield>
# <subfield code="2">gnd</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="653">
# <subfield code="a">Decoding Framework</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="653">
# <subfield code="a">Artificial Neural Network</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="653">
# <subfield code="a">Retinal Implant</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="653">
# <subfield code="a">Artificial Vision</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="653">
# <subfield code="a">Electrophysiology</subfield>
# </datafield>
# <datafield ind1="1" ind2=" " tag="700">
# <subfield code="8">3\p</subfield>
# <subfield code="a">Zrenner, Eberhart</subfield>
# <subfield code="e">Akademischer Betreuer</subfield>
# <subfield code="4">dgs</subfield>
# </datafield>
# <datafield ind1=" " ind2=" " tag="850">
# <subfield code="a">DE-101a</subfield>
# <subfield code="a">DE-101b</subfield>
# </datafield>
# <datafield ind1="4" ind2="0" tag="856">
# <subfield code="u">https://nbn-resolving.org/urn:nbn:de:bsz:21-dspace-994892</subfield>
# <subfield code="x">Resolving-System</subfield>
# </datafield>
# <datafield ind1=" " ind2="0" tag="856">
# <subfield code="u">https://d-nb.info/1253067287/34</subfield>
# <subfield code="x">Langzeitarchivierung Nationalbibliothek</subfield>
# </datafield>
# <datafield ind1="4" ind2=" " tag="856">
# <subfield code="u">https://publikationen.uni-tuebingen.de/xmlui/handle/10900/99489/</subfield>
# <subfield code="x">Verlag</subfield>
# <subfield code="z">kostenfrei</subfield>
# </datafield>
# <datafield ind1="4" ind2=" " tag="856">
# <subfield code="u">http://hdl.handle.net/10900/99489</subfield>
# <subfield code="x">Verlag</subfield>
# <subfield code="z">kostenfrei</subfield>
# </datafield>
# <datafield ind1="4" ind2=" " tag="856">
# <subfield code="u">http://dx.doi.org/10.15496/publikation-40870</subfield>
# <subfield code="x">Verlag</subfield>
# <subfield code="z">kostenfrei</subfield>
# </datafield>
# <datafield ind1="4" ind2=" " tag="856">
# <subfield code="u">http://nbn-resolving.de/urn:nbn:de:bsz:21-dspace-994892</subfield>
# <subfield code="x">Verlag</subfield>
# <subfield code="z">kostenfrei</subfield>
# </datafield>
# <datafield ind1="1" ind2=" " tag="883">
# <subfield code="8">1\p</subfield>
# <subfield code="a">npi</subfield>
# <subfield code="d">20220308</subfield>
# <subfield code="q">DE-101</subfield>
# <subfield code="u">https://d-nb.info/provenance/plan#npi</subfield>
# </datafield>
# <datafield ind1="1" ind2=" " tag="883">
# <subfield code="8">2\p</subfield>
# <subfield code="a">npi</subfield>
# <subfield code="d">20220308</subfield>
# <subfield code="q">DE-101</subfield>
# <subfield code="u">https://d-nb.info/provenance/plan#npi</subfield>
# </datafield>
# <datafield ind1="1" ind2=" " tag="883">
# <subfield code="8">3\p</subfield>
# <subfield code="a">npi</subfield>
# <subfield code="d">20220308</subfield>
# <subfield code="q">DE-101</subfield>
# <subfield code="u">https://d-nb.info/provenance/plan#npi</subfield>
# </datafield>
# <datafield ind1="0" ind2=" " tag="883">
# <subfield code="8">4\p</subfield>
# <subfield code="a">aeplcsh</subfield>
# <subfield code="c">0,01504</subfield>
# <subfield code="d">20220308</subfield>
# <subfield code="q">DE-101</subfield>
# <subfield code="u">https://d-nb.info/provenance/plan#aeplcsh</subfield>
# </datafield>
# <datafield ind1="0" ind2=" " tag="883">
# <subfield code="8">5\p</subfield>
# <subfield code="a">aeplcsh</subfield>
# <subfield code="c">0,01128</subfield>
# <subfield code="d">20220308</subfield>
# <subfield code="q">DE-101</subfield>
# <subfield code="u">https://d-nb.info/provenance/plan#aeplcsh</subfield>
# </datafield>
# <datafield ind1="0" ind2=" " tag="883">
# <subfield code="8">6\p</subfield>
# <subfield code="a">emakn</subfield>
# <subfield code="c">0,86774</subfield>
# <subfield code="d">20220308</subfield>
# <subfield code="q">DE-101</subfield>
# <subfield code="u">https://d-nb.info/provenance/plan#emakn</subfield>
# </datafield>
# <datafield ind1="0" ind2=" " tag="883">
# <subfield code="8">7\p</subfield>
# <subfield code="a">aepsg</subfield>
# <subfield code="c">0,99919</subfield>
# <subfield code="d">20220308</subfield>
# <subfield code="q">DE-101</subfield>
# <subfield code="u">https://d-nb.info/provenance/plan#aepsg</subfield>
# </datafield>
# <datafield ind1="r" ind2=" " tag="925">
# <subfield code="a">ro</subfield>
# <subfield code="a">rh</subfield>
# </datafield>
# </record>
